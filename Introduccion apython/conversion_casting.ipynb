# %% [markdown]
# # casting
# *el casting se refiere a cambiar un valor de un tipo de dsato a otro.

# %% [markdown]
# # Casting a int

# %%
numero_float= 3.14
print(int(numero_float))
# Out:
# 3

# %%
numero_str=input("Ingrese un numero")
print(type(numero_str))

# %%
num_strg=3.1234
print(float(num_strg))

# %% [markdown]
# # Casting a bool

# %%
num_int=0
print(bool(num_int))
# Out:
# False

# %%
num_float=1.0
print(print(num_float))
# Out:
# 1.0
# None

# %%
num_int=123
print (str(num_int))
print(type(str(num_int)))
# Out:
# 123
# <class 'str'>
